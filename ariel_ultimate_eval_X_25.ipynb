# %% [markdown]
# # Ariel ultimate eval

# %% [markdown]
# source (Huggingface): https://huggingface.co/spaces/ArielDrabkin/Solar-Panel-Detector

# %% [markdown]
# VII 25 with changes 18 X 25 and on
#
# *MD*

# %% [markdown]
# ## setup

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pds
# import cv2
from ultralytics import YOLO
# import torch
# from IPython.display import Image

# %%
pilot = "pilotPV_panels.v1i.yolov8-obb/data.yaml"
rzeszow = "rzeszowSolar panels seg.v2i.yolov8-obb/data.yaml"
synth = 'auto_pv_to_fine_tunning.v4i.yolov8-obb/data.yaml'
model_pt = "final-mosaic-augmentation.pt"

# %%
# model = YOLO(model=model_pt, task="segment", verbose=True)  # explicitly
model = YOLO(model=model_pt, verbose=True)
model.eval()
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %% [markdown]
# ## pilot data

# %% [markdown]
# deemed volatile across samples

# %%
results = model.val(data=pilot, single_cls=True, batch=64, iou=0.7)
# Out:
# Ultralytics 8.3.166 🚀 Python-3.12.3 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3406.6±1048.2 MB/s, size: 76.3 KB)
# val: Scanning /home/marekd6/ZPB/pilotPV_panels.v1i.yolov8-obb/test/labels.cache... 55 images, 1 backgrounds, 0 corrupt: 100%|██████████| 55/55 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.03s/it]
#                    all         55        227      0.546      0.429      0.402      0.207
# Speed: 3.6ms preprocess, 9.4ms inference, 0.0ms loss, 4.1ms postprocess per image
# Results saved to runs/detect/val26

# %% [markdown]
# #### box

# %%
results.box.mean_results() # Return mean of results, mp, mr, map50, map.
# Out:
# [np.float64(0.5457193326413479),
#  np.float64(0.42865662569307805),
#  np.float64(0.40150158853614587),
#  np.float64(0.2069373555096147)]

# %% [markdown]
# #### nbs

# %%
results.summary(decimals=3)
# Out:
# [{'Class': 'solar-panel',
#   'Images': np.int64(54),
#   'Instances': np.int64(227),
#   'Box-P': np.float64(0.546),
#   'Box-R': np.float64(0.429),
#   'Box-F1': np.float64(0.48),
#   'mAP50': np.float64(0.402),
#   'mAP50-95': np.float64(0.207)}]

# %%
results.summary(decimals=2)
# Out:
# [{'Class': 'solar-panel',
#   'Images': np.int64(54),
#   'Instances': np.int64(227),
#   'Box-P': np.float64(0.55),
#   'Box-R': np.float64(0.43),
#   'Box-F1': np.float64(0.48),
#   'mAP50': np.float64(0.4),
#   'mAP50-95': np.float64(0.21)}]

# %% [markdown]
# nothing fancy

# %% [markdown]
# ## Rzeszów data

# %% [markdown]
# featuring very simple cases

# %% [markdown]
# ### val

# %%
results = model.val(data=rzeszow, single_cls=True, batch=64, iou=0.7)
# Out:
# Ultralytics 8.3.166 🚀 Python-3.12.3 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# val: Fast image access ✅ (ping: 0.5±0.3 ms, read: 44.1±20.8 MB/s, size: 40.3 KB)
# val: Scanning /home/marekd6/ZPB/rzeszowSolar panels seg.v2i.yolov8-obb/valid/labels.cache... 674 images, 4 backgrounds, 9 corrupt: 100%|██████████| 674/674 [00:00<?, ?it/s]
# val: /home/marekd6/ZPB/rzeszowSolar panels seg.v2i.yolov8-obb/valid/images/PV03_331396_1192539_jpg.rf.04155b245de5302e1204d1c428775cca.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.1224557]
# val: /home/marekd6/ZPB/rzeszowSolar panels seg.v2i.yolov8-obb/valid/images/PV03_340770_1179246_jpg.rf.f33e50ed777a6bdf5218ba6d584911fa.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0267125]
# ...

# %% [markdown]
# #### box

# %%
results.box.mean_results() # Return mean of results, mp, mr, map50, map.
# Out:
# [np.float64(0.837420612160192),
#  np.float64(0.720410426479982),
#  np.float64(0.7647818779585915),
#  np.float64(0.5282438041761167)]

# %% [markdown]
# #### nbs

# %%
results.summary(decimals=3)
# Out:
# [{'Class': 'solar-panel',
#   'Images': np.int64(661),
#   'Instances': np.int64(2767),
#   'Box-P': np.float64(0.837),
#   'Box-R': np.float64(0.72),
#   'Box-F1': np.float64(0.775),
#   'mAP50': np.float64(0.765),
#   'mAP50-95': np.float64(0.528)}]

# %%
results.summary(decimals=2)
# Out:
# [{'Class': 'solar-panel',
#   'Images': np.int64(661),
#   'Instances': np.int64(2767),
#   'Box-P': np.float64(0.84),
#   'Box-R': np.float64(0.72),
#   'Box-F1': np.float64(0.77),
#   'mAP50': np.float64(0.76),
#   'mAP50-95': np.float64(0.53)}]

# %% [markdown]
# rather average quality

# %% [markdown]
# ### test

# %%
results = model.val(data=rzeszow, single_cls=True, batch=64, iou=0.7, split="test")
# Out:
# Ultralytics 8.3.166 🚀 Python-3.12.3 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# val: Fast image access ✅ (ping: 0.4±0.4 ms, read: 73.3±27.8 MB/s, size: 40.8 KB)
# val: Scanning /home/marekd6/ZPB/rzeszowSolar panels seg.v2i.yolov8-obb/test/labels.cache... 441 images, 4 backgrounds, 2 corrupt: 100%|██████████| 441/441 [00:00<?, ?it/s]
# val: /home/marekd6/ZPB/rzeszowSolar panels seg.v2i.yolov8-obb/test/images/PV08_332044_1180242_jpg.rf.871f9b07835235a19da8d5dd7b35a7c0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.1781085 1.3869264]
# val: /home/marekd6/ZPB/rzeszowSolar panels seg.v2i.yolov8-obb/test/images/PV08_332121_1180416_jpg.rf.7b8ebd6cb336466696bca2e8e346d097.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0421456]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:08<00:00,  1.22s/it]
# ...

# %% [markdown]
# #### box

# %%
results.box.mean_results() # Return mean of results, mp, mr, map50, map.
# Out:
# [np.float64(0.8671749337708281),
#  np.float64(0.8291962174940898),
#  np.float64(0.8656722194666244),
#  np.float64(0.6037546845209791)]

# %% [markdown]
# #### nbs

# %%
results.summary(decimals=3)
# Out:
# [{'Class': 'solar-panel',
#   'Images': np.int64(435),
#   'Instances': np.int64(1692),
#   'Box-P': np.float64(0.867),
#   'Box-R': np.float64(0.829),
#   'Box-F1': np.float64(0.848),
#   'mAP50': np.float64(0.866),
#   'mAP50-95': np.float64(0.604)}]

# %% [markdown]
# ok

# %% [markdown]
# ## synthetic data

# %% [markdown]
# featuring very simple cases

# %% [markdown]
# ### val

# %%
results = model.val(data=synth, single_cls=True, batch=64, iou=0.7)
# Out:
# Ultralytics 8.3.166 🚀 Python-3.12.3 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 87.8±30.0 MB/s, size: 54.2 KB)
# val: Scanning /home/marekd6/ZPB/modelling/modelling/auto_pv_to_fine_tunning.v4i.yolov8-obb/valid/labels... 12 images, 0 backgrounds, 0 corrupt: 100%|██████████| 12/12 [00:00<00:00, 342.92it/s]
# val: New cache created: /home/marekd6/ZPB/modelling/modelling/auto_pv_to_fine_tunning.v4i.yolov8-obb/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.53it/s]
#                    all         12         35      0.565        0.6      0.586      0.272
# Speed: 1.6ms preprocess, 14.1ms inference, 0.0ms loss, 17.4ms postprocess per image
# Results saved to runs/detect/val

# %% [markdown]
# #### box

# %%
results.box.mean_results() # Return mean of results, mp, mr, map50, map.
# Out:
# [np.float64(0.5645864459653147),
#  np.float64(0.6),
#  np.float64(0.5857143802178753),
#  np.float64(0.27162707261845453)]

# %% [markdown]
# #### nbs

# %%
results.summary(decimals=3)
# Out:
# [{'Class': 'solar-panel',
#   'Images': np.int64(12),
#   'Instances': np.int64(35),
#   'Box-P': np.float64(0.565),
#   'Box-R': np.float64(0.6),
#   'Box-F1': np.float64(0.582),
#   'mAP50': np.float64(0.586),
#   'mAP50-95': np.float64(0.272)}]

# %%
results.summary(decimals=2)
# Out:
# [{'Class': 'solar-panel',
#   'Images': np.int64(12),
#   'Instances': np.int64(35),
#   'Box-P': np.float64(0.56),
#   'Box-R': np.float64(0.6),
#   'Box-F1': np.float64(0.58),
#   'mAP50': np.float64(0.59),
#   'mAP50-95': np.float64(0.27)}]

# %% [markdown]
# nice

# %% [markdown]
# ### test

# %%
results = model.val(data=synth, single_cls=True, batch=64, iou=0.7, split="test")
# Out:
# Ultralytics 8.3.166 🚀 Python-3.12.3 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 46.1±7.4 MB/s, size: 51.6 KB)
# val: Scanning /home/marekd6/ZPB/modelling/modelling/auto_pv_to_fine_tunning.v4i.yolov8-obb/test/labels...:   0%|          | 0/18 [00:00<?, ?it/s]
# val: Scanning /home/marekd6/ZPB/modelling/modelling/auto_pv_to_fine_tunning.v4i.yolov8-obb/test/labels... 18 images, 0 backgrounds, 0 corrupt: 100%|██████████| 18/18 [00:00<00:00, 258.64it/s]
# val: New cache created: /home/marekd6/ZPB/modelling/modelling/auto_pv_to_fine_tunning.v4i.yolov8-obb/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.28s/it]
#                    all         18         32      0.337       0.25      0.273      0.109
# Speed: 3.4ms preprocess, 28.8ms inference, 0.0ms loss, 8.2ms postprocess per image
# Results saved to runs/detect/val2

# %% [markdown]
# #### box

# %%
results.box.mean_results() # Return mean of results, mp, mr, map50, map.
# Out:
# [np.float64(0.3369520834263724),
#  np.float64(0.25),
#  np.float64(0.272642908205397),
#  np.float64(0.1085074638796979)]

# %% [markdown]
# #### nbs

# %%
results.summary(decimals=3)
# Out:
# [{'Class': 'solar-panel',
#   'Images': np.int64(18),
#   'Instances': np.int64(32),
#   'Box-P': np.float64(0.337),
#   'Box-R': np.float64(0.25),
#   'Box-F1': np.float64(0.287),
#   'mAP50': np.float64(0.273),
#   'mAP50-95': np.float64(0.109)}]

# %% [markdown]
# barely

# %% [markdown]
# ### train

# %%
results = model.val(data=synth, single_cls=True, batch=64, iou=0.7, split="train")
# Out:
# Ultralytics 8.3.166 🚀 Python-3.12.3 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# val: Fast image access ✅ (ping: 0.2±0.3 ms, read: 53.2±32.6 MB/s, size: 72.4 KB)
# val: Scanning /home/marekd6/ZPB/modelling/modelling/auto_pv_to_fine_tunning.v4i.yolov8-obb/train/labels... 150 images, 0 backgrounds, 0 corrupt: 100%|██████████| 150/150 [00:00<00:00, 332.46it/s]
# val: New cache created: /home/marekd6/ZPB/modelling/modelling/auto_pv_to_fine_tunning.v4i.yolov8-obb/train/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:10<00:00,  3.60s/it]
#                    all        150        374      0.463       0.38      0.326      0.149
# Speed: 5.6ms preprocess, 14.4ms inference, 0.0ms loss, 12.5ms postprocess per image
# Results saved to runs/detect/val3

# %% [markdown]
# #### box

# %%
results.box.mean_results() # Return mean of results, mp, mr, map50, map.
# Out:
# [np.float64(0.4630872220371468),
#  np.float64(0.37967914438502676),
#  np.float64(0.32612186080872535),
#  np.float64(0.14878230438539966)]

# %% [markdown]
# #### nbs

# %%
results.summary(decimals=3)
# Out:
# [{'Class': 'solar-panel',
#   'Images': np.int64(150),
#   'Instances': np.int64(374),
#   'Box-P': np.float64(0.463),
#   'Box-R': np.float64(0.38),
#   'Box-F1': np.float64(0.417),
#   'mAP50': np.float64(0.326),
#   'mAP50-95': np.float64(0.149)}]

# %% [markdown]
# good enough
