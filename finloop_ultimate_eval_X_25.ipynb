# %% [markdown]
# # Finloop ultimate eval

# %% [markdown]
# source (Huggingface): finloop/yolov8s-seg-solar-panels

# %% [markdown]
# TODO: fix synthetic dataset

# %% [markdown]
# with changes 18 X 25
#
# MD

# %% [markdown]
# note: a dual-use model (detection + instance segmentation)

# %%
import numpy as np
import matplotlib.pyplot as plt
# import pandas as pds
# import cv2
from ultralytics import YOLO
# import torch
from IPython.display import Image

# %%
pilot = "pilotPV_panels.v1i.yolov8-obb/pilotPV_panels.v1i.yolov8-obb/data.yaml"
pilot = "pilotPV_panels.v1i.yolov8-obb/data.yaml"
rzeszow = "rzeszowSolar panels seg.v2i.yolov8-obb/data.yaml"
synth = 'synth-pv.v1i.yolov8/data.yaml'
model_pt = "best.pt"

# %%
# model = YOLO(model=model_pt, task="segment", verbose=True)
model = YOLO(model=model_pt, verbose=True)
model.eval()
# Out:
# YOLO(
#   (model): SegmentationModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): Conv(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (4): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (5): Conv(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (6): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (7): Conv(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (8): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (9): SPPF(
#         (cv1): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (10): Upsample(scale_factor=2.0, mode='nearest')
#       (11): Concat()
#       (12): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (13): Upsample(scale_factor=2.0, mode='nearest')
#       (14): Concat()
#       (15): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (16): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (17): Concat()
#       (18): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (19): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (20): Concat()
#       (21): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (22): Segment(
#         (cv2): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(512, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (cv3): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(512, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (dfl): DFL(
#           (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (proto): Proto(
#           (cv1): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (upsample): ConvTranspose2d(128, 128, kernel_size=(2, 2), stride=(2, 2))
#           (cv2): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (cv4): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(512, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# ## pilot data

# %%
results = model.val(data=pilot, single_cls=True, batch=64, iou=0.7)
# Out:
# Ultralytics 8.3.166 🚀 Python-3.12.3 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# YOLOv8s-seg summary (fused): 85 layers, 11,779,987 parameters, 0 gradients, 42.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 203.3±55.6 MB/s, size: 80.0 KB)
# val: Scanning /home/marekd6/ZPB/pilotPV_panels.v1i.yolov8-obb/test/labels.cache... 55 images, 1 backgrounds, 0 corrupt: 100%|██████████| 55/55 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0%|          | 0/1 [00:00<?, ?it/s]
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:07<00:00,  7.33s/it]
#                    all         55        227      0.547      0.414      0.379      0.202      0.202      0.159     0.0712     0.0151
# Speed: 0.8ms preprocess, 116.9ms inference, 0.0ms loss, 4.7ms postprocess per image
# Results saved to runs/segment/val32

# %% [markdown]
# #### box

# %%
results.box.mean_results() # Return mean of results, mp, mr, map50, map.
# Out:
# [np.float64(0.5471944811213388),
#  np.float64(0.41409691629955947),
#  np.float64(0.3793272027934472),
#  np.float64(0.20191744439421133)]

# %% [markdown]
# #### seg

# %%
results.seg.mean_results() # Return mean of results, mp, mr, map50, map.
# Out:
# [np.float64(0.2015821610819426),
#  np.float64(0.15859030837004406),
#  np.float64(0.07119147971005486),
#  np.float64(0.015133100319693338)]

# %% [markdown]
# #### nbs

# %%
results.summary(decimals=3)
# Out:
# [{'Class': 'solar-panel',
#   'Images': np.int64(54),
#   'Instances': np.int64(227),
#   'Box-P': np.float64(0.547),
#   'Box-R': np.float64(0.414),
#   'Box-F1': np.float64(0.471),
#   'mAP50': np.float64(0.379),
#   'mAP50-95': np.float64(0.202),
#   'Mask-P': np.float64(0.202),
#   'Mask-R': np.float64(0.159),
#   'Mask-F1': np.float64(0.178)}]

# %%
results.summary(decimals=2)
# Out:
# [{'Class': 'solar-panel',
#   'Images': np.int64(54),
#   'Instances': np.int64(227),
#   'Box-P': np.float64(0.55),
#   'Box-R': np.float64(0.41),
#   'Box-F1': np.float64(0.47),
#   'mAP50': np.float64(0.38),
#   'mAP50-95': np.float64(0.2),
#   'Mask-P': np.float64(0.2),
#   'Mask-R': np.float64(0.16),
#   'Mask-F1': np.float64(0.18)}]

# %% [markdown]
# ## Rzeszów data

# %% [markdown]
# ### val

# %%
results = model.val(data=rzeszow, single_cls=True, batch=64, iou=0.7)
# Out:
# Ultralytics 8.3.166 🚀 Python-3.12.3 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# val: Fast image access ✅ (ping: 0.1±0.0 ms, read: 36.6±28.6 MB/s, size: 37.3 KB)
# val: Scanning /home/marekd6/ZPB/rzeszowSolar panels seg.v2i.yolov8-obb/valid/labels.cache... 674 images, 4 backgrounds, 9 corrupt: 100%|██████████| 674/674 [00:00<?, ?it/s]
# val: /home/marekd6/ZPB/rzeszowSolar panels seg.v2i.yolov8-obb/valid/images/PV03_331396_1192539_jpg.rf.04155b245de5302e1204d1c428775cca.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.1224557]
# val: /home/marekd6/ZPB/rzeszowSolar panels seg.v2i.yolov8-obb/valid/images/PV03_340770_1179246_jpg.rf.f33e50ed777a6bdf5218ba6d584911fa.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0267125]
# val: /home/marekd6/ZPB/rzeszowSolar panels seg.v2i.yolov8-obb/valid/images/PV03_340771_1179280_jpg.rf.be6103656b4115816f9b56ca91b0ee7f.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0337802]
# val: /home/marekd6/ZPB/rzeszowSolar panels seg.v2i.yolov8-obb/valid/images/PV03_341178_1177239_jpg.rf.18301bf469f41110b02448a766ad508f.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.1199216]
# val: /home/marekd6/ZPB/rzeszowSolar panels seg.v2i.yolov8-obb/valid/images/PV03_343715_1200715_jpg.rf.577e3043ea25d32702069b9e88b2ae2c.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.4017956 1.3594282]
# val: /home/marekd6/ZPB/rzeszowSolar panels seg.v2i.yolov8-obb/valid/images/PV03_344130_1199345_jpg.rf.20b3b7e68d5d3b3eda04e9f19b01686c.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.1162397 1.2075286 1.0701448]
# val: /home/marekd6/ZPB/rzeszowSolar panels seg.v2i.yolov8-obb/valid/images/PV03_344213_1199412_jpg.rf.0265c0da538ca113201801f71389ef5c.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.212682 1.314927]
# val: /home/marekd6/ZPB/rzeszowSolar panels seg.v2i.yolov8-obb/valid/images/PV03_346080_1193549_jpg.rf.19419256b31c7ba454e613c3455530e9.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.1421947]
# val: /home/marekd6/ZPB/rzeszowSolar panels seg.v2i.yolov8-obb/valid/images/PV03_348518_1168678_jpg.rf.a83a3082df90cf02ceea61845c875fe9.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0189424]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   9%|▉         | 1/11 [00:02<00:24,  2.44s/it]
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):  18%|█▊        | 2/11 [00:15<01:16,  8.45s/it]
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [01:58<00:00, 10.81s/it]
#                    all        665       2767      0.902      0.791      0.831      0.621      0.879       0.73      0.789      0.436
# Speed: 1.2ms preprocess, 158.0ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/segment/val33

# %% [markdown]
# #### box

# %%
results.box.mean_results() # Return mean of results, mp, mr, map50, map.
# Out:
# [np.float64(0.9019038050062954),
#  np.float64(0.7908167649703696),
#  np.float64(0.8307094907693291),
#  np.float64(0.6205611734579932)]

# %% [markdown]
# #### seg

# %%
results.seg.mean_results() # Return mean of results, mp, mr, map50, map.
# Out:
# [np.float64(0.8791002489760318),
#  np.float64(0.7303939284423563),
#  np.float64(0.7887852737158978),
#  np.float64(0.43610919708373164)]

# %% [markdown]
# #### nbs

# %%
results.summary(decimals=3)
# Out:
# [{'Class': 'solar-panel',
#   'Images': np.int64(661),
#   'Instances': np.int64(2767),
#   'Box-P': np.float64(0.902),
#   'Box-R': np.float64(0.791),
#   'Box-F1': np.float64(0.843),
#   'mAP50': np.float64(0.831),
#   'mAP50-95': np.float64(0.621),
#   'Mask-P': np.float64(0.879),
#   'Mask-R': np.float64(0.73),
#   'Mask-F1': np.float64(0.798)}]

# %%
results.summary(decimals=2)
# Out:
# [{'Class': 'solar-panel',
#   'Images': np.int64(661),
#   'Instances': np.int64(2767),
#   'Box-P': np.float64(0.9),
#   'Box-R': np.float64(0.79),
#   'Box-F1': np.float64(0.84),
#   'mAP50': np.float64(0.83),
#   'mAP50-95': np.float64(0.62),
#   'Mask-P': np.float64(0.88),
#   'Mask-R': np.float64(0.73),
#   'Mask-F1': np.float64(0.8)}]

# %% [markdown]
# ### test

# %%
results = model.val(data=rzeszow, single_cls=True, batch=64, iou=0.7, split="test")
# Out:
# Ultralytics 8.3.166 🚀 Python-3.12.3 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# val: Fast image access ✅ (ping: 0.1±0.0 ms, read: 32.4±18.9 MB/s, size: 24.4 KB)
# val: Scanning /home/marekd6/ZPB/rzeszowSolar panels seg.v2i.yolov8-obb/test/labels.cache... 441 images, 4 backgrounds, 2 corrupt: 100%|██████████| 441/441 [00:00<?, ?it/s]
# val: /home/marekd6/ZPB/rzeszowSolar panels seg.v2i.yolov8-obb/test/images/PV08_332044_1180242_jpg.rf.871f9b07835235a19da8d5dd7b35a7c0.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.1781085 1.3869264]
# val: /home/marekd6/ZPB/rzeszowSolar panels seg.v2i.yolov8-obb/test/images/PV08_332121_1180416_jpg.rf.7b8ebd6cb336466696bca2e8e346d097.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0421456]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0%|          | 0/7 [00:00<?, ?it/s]
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):  14%|█▍        | 1/7 [00:13<01:23, 13.94s/it]
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):  29%|██▊       | 2/7 [00:27<01:10, 14.01s/it]
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [01:28<00:00, 12.59s/it]
#                    all        439       1692      0.924      0.899      0.935      0.696      0.861      0.839      0.873      0.519
# Speed: 1.8ms preprocess, 171.7ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/segment/val34

# %% [markdown]
# #### box

# %%
results.box.mean_results() # Return mean of results, mp, mr, map50, map.
# Out:
# [np.float64(0.9241005774317743),
#  np.float64(0.8994777758657113),
#  np.float64(0.9353602653935182),
#  np.float64(0.6957919073514963)]

# %% [markdown]
# #### seg

# %%
results.seg.mean_results() # Return mean of results, mp, mr, map50, map.
# Out:
# [np.float64(0.8613973519848999),
#  np.float64(0.8386524822695035),
#  np.float64(0.872804023821086),
#  np.float64(0.5190337759556243)]

# %% [markdown]
# #### nbs

# %%
results.summary(decimals=3)
# Out:
# [{'Class': 'solar-panel',
#   'Images': np.int64(435),
#   'Instances': np.int64(1692),
#   'Box-P': np.float64(0.924),
#   'Box-R': np.float64(0.899),
#   'Box-F1': np.float64(0.912),
#   'mAP50': np.float64(0.935),
#   'mAP50-95': np.float64(0.696),
#   'Mask-P': np.float64(0.861),
#   'Mask-R': np.float64(0.839),
#   'Mask-F1': np.float64(0.85)}]

# %%
results.summary(decimals=2)
# Out:
# [{'Class': 'solar-panel',
#   'Images': np.int64(435),
#   'Instances': np.int64(1692),
#   'Box-P': np.float64(0.92),
#   'Box-R': np.float64(0.9),
#   'Box-F1': np.float64(0.91),
#   'mAP50': np.float64(0.94),
#   'mAP50-95': np.float64(0.7),
#   'Mask-P': np.float64(0.86),
#   'Mask-R': np.float64(0.84),
#   'Mask-F1': np.float64(0.85)}]

# %% [markdown]
# ## synthetic data 1

# %%
results = model.val(data=synth, single_cls=True, batch=64, iou=0.7)
# Out:
# Ultralytics 8.3.166 🚀 Python-3.12.3 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1118.5±587.2 MB/s, size: 42.7 KB)
# val: Scanning /home/marekd6/ZPB/synth-pv.v1i.yolov8/test/labels... 400 images, 0 backgrounds, 0 corrupt: 100%|██████████| 400/400 [00:00<00:00, 1012.21it/s]
# val: New cache created: /home/marekd6/ZPB/synth-pv.v1i.yolov8/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0%|          | 0/7 [00:00<?, ?it/s]
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):  14%|█▍        | 1/7 [00:06<00:37,  6.18s/it]
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):  29%|██▊       | 2/7 [00:12<00:30,  6.11s/it]
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:49<00:00,  7.07s/it]
#                    all        400        400      0.215       0.19     0.0731     0.0305      0.033     0.0275     0.0043   0.000606
# Speed: 1.5ms preprocess, 104.8ms inference, 0.0ms loss, 2.6ms postprocess per image
# Results saved to runs/segment/val39

# %% [markdown]
# #### box

# %%
results.box.mean_results() # Return mean of results, mp, mr, map50, map.
# Out:
# [np.float64(0.21531626598695217),
#  np.float64(0.19),
#  np.float64(0.07310553960149158),
#  np.float64(0.030466427316950363)]

# %% [markdown]
# #### seg

# %%
results.seg.mean_results() # Return mean of results, mp, mr, map50, map.
# Out:
# [np.float64(0.03299388823887258),
#  np.float64(0.0275),
#  np.float64(0.004299933648685423),
#  np.float64(0.0006056327980521472)]

# %% [markdown]
# #### nbs

# %%
results.summary(decimals=3)
# Out:
# [{'Class': 'solar-panel',
#   'Images': np.int64(400),
#   'Instances': np.int64(400),
#   'Box-P': np.float64(0.215),
#   'Box-R': np.float64(0.19),
#   'Box-F1': np.float64(0.202),
#   'mAP50': np.float64(0.073),
#   'mAP50-95': np.float64(0.03),
#   'Mask-P': np.float64(0.033),
#   'Mask-R': np.float64(0.028),
#   'Mask-F1': np.float64(0.03)}]

# %%
results.summary(decimals=2)
# Out:
# [{'Class': 'solar-panel',
#   'Images': np.int64(400),
#   'Instances': np.int64(400),
#   'Box-P': np.float64(0.22),
#   'Box-R': np.float64(0.19),
#   'Box-F1': np.float64(0.2),
#   'mAP50': np.float64(0.07),
#   'mAP50-95': np.float64(0.03),
#   'Mask-P': np.float64(0.03),
#   'Mask-R': np.float64(0.03),
#   'Mask-F1': np.float64(0.03)}]

# %% [markdown]
# ## synthetic data 2

# %%
# import torch

# %%
# torch.cuda.empty_cache()

# %%
results = model.val(data=synth, single_cls=True, batch=8, iou=0.7, imgsz=1728)
# Out:
# Ultralytics 8.3.166 🚀 Python-3.12.3 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# YOLOv8s-seg summary (fused): 85 layers, 11,779,987 parameters, 0 gradients, 42.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 820.9±245.8 MB/s, size: 119.9 KB)
# val: Scanning /home/marekd6/ZPB/synth-pv.v1i.yolov8/test/labels.cache... 400 images, 0 backgrounds, 0 corrupt: 100%|██████████| 400/400 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0%|          | 0/50 [00:00<?, ?it/s]
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   2%|▏         | 1/50 [00:03<02:38,  3.23s/it]
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   4%|▍         | 2/50 [00:06<02:46,  3.47s/it]
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 50/50 [06:25<00:00,  7.71s/it]
#                    all        400        400   0.000724     0.0025   4.24e-05   4.24e-06          0          0          0          0
# Speed: 3.3ms preprocess, 878.6ms inference, 0.0ms loss, 5.4ms postprocess per image
# Results saved to runs/segment/val43

# %% [markdown]
# #### box

# %%
results.box.mean_results() # Return mean of results, mp, mr, map50, map.
# Out:
# [np.float64(0.0007244764308315021),
#  np.float64(0.0025),
#  np.float64(4.240850422287334e-05),
#  np.float64(4.240850422287334e-06)]

# %% [markdown]
# #### seg

# %%
results.seg.mean_results() # Return mean of results, mp, mr, map50, map.
# Out:
# [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]

# %% [markdown]
# #### nbs

# %%
results.summary(decimals=3)
# Out:
# [{'Class': 'solar-panel',
#   'Images': np.int64(400),
#   'Instances': np.int64(400),
#   'Box-P': np.float64(0.001),
#   'Box-R': np.float64(0.002),
#   'Box-F1': np.float64(0.001),
#   'mAP50': np.float64(0.0),
#   'mAP50-95': np.float64(0.0),
#   'Mask-P': np.float64(0.0),
#   'Mask-R': np.float64(0.0),
#   'Mask-F1': np.float64(0.0)}]

# %%
results.summary(decimals=2)
# Out:
# [{'Class': 'solar-panel',
#   'Images': np.int64(400),
#   'Instances': np.int64(400),
#   'Box-P': np.float64(0.0),
#   'Box-R': np.float64(0.0),
#   'Box-F1': np.float64(0.0),
#   'mAP50': np.float64(0.0),
#   'mAP50-95': np.float64(0.0),
#   'Mask-P': np.float64(0.0),
#   'Mask-R': np.float64(0.0),
#   'Mask-F1': np.float64(0.0)}]
